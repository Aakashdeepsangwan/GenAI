# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
"""
Embeddings : Numerical representation of text
In order to store these numerical representations we need databses and they are called vector databases


-- Different Embedding models has different dimensions
    - chatGPT Embeddings has 1500 
    - HuggingFace Embeddings has 384
so it convert each word into that specific dimension
"""

# %%
word_embeddings = {
    "cat" : [0.8,0.6],
    "kitten" : [0.75,0.65],
    "dog" : [0.7,0.3],
    "puppy" : [0.65, 0.35],
    "car" : [-0.5,0.2],
    "truck" : [-0.45,0.15]
}

# %%
fix, ax = plt.subplots(figsize=(8,6))


for word, coords in word_embeddings.items() :
    ax.scatter(coords[0],coords[1], s=100)
    ax.annotate(word,(coords[0],coords[1]), xytext=(5,5),
    textcoords= 'offset points'
    )


ax.set_xlabel('Dimension 1')
ax.set_ylabel('Dimension 2')
ax.set_title("simplified word embeddings in 2d space")
ax.grid(True, alpha = 0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Measuring Cosine Similarity

# %%
def cosine_similarity(vec1, vec2) :
    """
    Measures the angle b/w two vectors
    1) result close to 1 : very similar
    2) result close to 0 : not related
    3) result close to -1 : opposite meaning
    """
    
    dot_product = np.dot(vec1,vec2)
    norm_a = np.linalg.norm(vec1)
    norm_b = np.linalg.norm(vec2)
    return dot_product/ (norm_a*norm_b)

# %%
# example

cat_vector = [0.8,0.6,0.3]
kitten_vector = [0.75, 0.65, 0.35]
car_vector = [-0.5, 0.2, 0.1]

cat_kitten_similarity = cosine_similarity(cat_vector, kitten_vector)
print(cat_kitten_similarity)

# the result is almost close to 1
# Out:
# 0.9966186334192181

# %%
cosine_similarity(car_vector, cat_vector)
# it's a negative value mean, both embeddings are opposite of each other
# as both words are no way related
# Out:
# np.float64(-0.43718588548916804)
